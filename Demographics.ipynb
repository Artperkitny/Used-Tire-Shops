# %% [markdown]
# C. Compile a several demographic variables (ideally at a census tract or similar level of granularity) and overlay onto the map from Part B. These variables at a minimum include:
#
# a) income,
#
# b) language spoken (or geometries),
#
# c) population density (to normalize for the amount of retail shops per 100k people),
#
# d) Digital Divide Index or some other metric of internet connectivity
#
# DELIVERABLE: A mapped visualization of the above variables with the retail shop locations
#     from Part B, the corresponding shapefiles for the above variables, and an updated spreadsheet that pairs these variables to the spreadsheet from Part B.

# %%
import pandas as pd
import geopandas as gp
import requests
from tqdm import tqdm
from shapely.geometry import shape 
import pyproj
from shapely.ops import transform
from functools import partial

from config import QKEY

pd.set_option('display.max_colwidth', 20)
pd.set_option('display.max_row', 2000)

# %%
df = pd.read_csv('files/tire_shops.csv')

# %% [markdown]
# # Income

# %%
def get_income_and_geo_id(row):
    url = f'https://quantmaps.com/api/locations/detail/2019/TRACT/?coords={row.lat},{row.lng}'
    response = requests.get(url, headers={"Authorization": QKEY}, params = {"fields":"median_household_income,total_population,geom"})
    response_dict = response.json()
    return response_dict['geo_id'], response_dict['median_household_income'], response_dict['total_population'], response_dict['geom']

# %%
for n, row in tqdm(df.iterrows(), total=len(df)):
    geo_id, income, total_pop, geometries = get_income_and_geo_id(row)
    df.loc[n, 'geo_id'] = geo_id
    df.loc[n, 'income'] = income
    df.loc[n, 'total_pop'] = total_pop
    df.loc[n, 'geom'] = shape(geometries)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 89/89 [00:26<00:00,  3.39it/s]

# %% [markdown]
# # Language Spoken: percentage of non-English speakers

# %%
language_df = pd.read_csv('ACSST5Y2018.S1602_data_with_overlays_2020-10-31T111916.csv')
headers_df = pd.read_csv('ACSST5Y2018.S1602_metadata_2020-10-31T111916.csv')
language_df = language_df[['GEO_ID', 'S1602_C04_001E']][1:]
language_df["GEO_ID"] = language_df.GEO_ID.apply(lambda x: x[9:])
language_df = language_df.rename(columns={'GEO_ID':'geo_id', "S1602_C04_001E":headers_df.loc[headers_df['GEO_ID']=='S1602_C04_001E'].id.item()})
language_df.head()
# Out:
#         geo_id  \
# 1  06001400100
# 2  06001400200
# 3  06001400300
# 4  06001400400
# 5  06001400500
#
#   Estimate!!Percent limited English-speaking households!!All households
# 1                  1.5
# 2                  0.0
# 3                  8.1
# 4                  1.2
# 5                  1.4

# %%
df = df.merge(language_df, on='geo_id', how='left')

# %% [markdown]
# # Internet Connectivity

# %%
internet_df = pd.read_csv('ACSST5Y2018.S2801_data_with_overlays_2020-10-31T111552.csv')
headers_df = pd.read_csv('ACSST5Y2018.S2801_metadata_2020-10-31T111552.csv')
internet_df = internet_df[['GEO_ID', 'S2801_C02_012E']][1:]
internet_df["GEO_ID"] = internet_df.GEO_ID.apply(lambda x: x[9:])
internet_df = internet_df.rename(columns={'GEO_ID':'geo_id', "S2801_C02_012E":headers_df.loc[headers_df['GEO_ID']=='S2801_C02_012E'].id.item()})
internet_df.head()
# Out:
#         geo_id  \
# 1  06001400100
# 2  06001400200
# 3  06001400300
# 4  06001400400
# 5  06001400500
#
#   Estimate!!Percent!!TYPE OF INTERNET SUBSCRIPTIONS!!With an Internet subscription
# 1                 96.3
# 2                 96.7
# 3                 89.9
# 4                 94.6
# 5                 95.1

# %%
df = df.merge(internet_df, on='geo_id', how='left')

# %% [markdown]
# # Population Density

# %%
def get_pop_density(row):
    proj = partial(pyproj.transform, pyproj.Proj(init='epsg:4326'), pyproj.Proj(init='epsg:3857'))
    projected_area = transform(proj, row.geom).area
    return round(row.total_pop/(projected_area*0.00000038610)*1.66)

# %%
df['pop_density'] = df.apply(get_pop_density, axis=1)

# %% [markdown]
# # Make GEO df and Clean

# %%
# df = pd.read_csv('demographics.csv')
# df = df.drop('Unnamed: 0', axis=1)
df = df.rename(columns={
    "Estimate!!Percent limited English-speaking households!!All households": "% Non-English",
    "Estimate!!Percent!!TYPE OF INTERNET SUBSCRIPTIONS!!With an Internet subscription": "% Internet",
    "pop_density": "Pop Density",
    "geo_id": "Census Tract ID",
    'income': 'Income',
    'geom': 'geometry'
})

gdf = gp.GeoDataFrame(df[['Census Tract ID', 
                         '% Non-English', 
                         '% Internet',
                         'Pop Density',
                         'Income',
                         'geometry']])

# %%
df.to_csv('shops.csv', index=False)
gdf.to_file('tracts.shp')
# Out:
# c:\users\art perkitny\anaconda3\lib\site-packages\geopandas\io\file.py:108: FionaDeprecationWarning: Use fiona.Env() instead.
#   with fiona.drivers():

# %%
gdf.dtypes
# Out:
# Census Tract ID     object
# % Non-English       object
# % Internet          object
# Pop Density          int64
# Income             float64
# geometry            object
# dtype: object

# %%
df
# Out:
#                    name              address  phone_number      lat       lng  \
# 0   1-800EveryRim OE...  12078 Florence A...   56269201090  33.9347 -118.0745
# 1           A & V Tires  1610 Oxnard Blvd...   80538511920  34.2168 -119.1771
# 2         Aal STAR TIRE  31162 San Clemen...   51048952180  37.6090 -122.0522
# 3   Able Tire & Brak...  7090 Redwood Blv...   41589741250  38.1004 -122.5669
# 4   Arcata Used Rire...  437 G Street Arc...   70782279090  40.8652 -124.0876
# 5   Balswick Tire Sh...  417 N. Golden St...   20963458820  37.4970 -120.8485
# 6     Bob's Tire Center  2300 Esplanade C...   53089584730  39.7529 -121.8572
# 7     Bruce's Tire Inc.  2420 Prune Ave. ...   51058014410  37.5062 -121.9385
# 8             Buds Tire  8651 Indiana Ave...   95135113190  33.9230 -117.4264
# 9    Bymar Tire & Brake  25631 Taladro Ci...   94976873810  33.6195 -117.6835
# 10           Cains Tire  1531 4th Street ...   41545329420  37.9735 -122.5348
# 11     Calderon's Tires  454 S. Bascom Av...   40829736000  37.3205 -121.9314
# 12         Carlton Tire  2335 South Main ...   70726367700  39.0229 -122.9150
# 13  Caroll's Tire Wa...  981 W. North Gra...   55978150400  36.0976 -119.0393
# 14  Chuy's Tire Service  1539 . Lincoln A...   62679776150  34.1729 -118.1602
# 15  Clerou Tire Co.,...  530 E. 21st Stre...   66132460690  35.3767 -118.9950
# 16  Commercial Tire Co.  3366 Leonis Blvd...   32358315610  33.9999 -118.2058
# 17         Country Tire  15290 River Road...   70786929290  38.5105 -122.9855
# 4                True            Review  https://www.yelp...
# 5                True            Review  https://www.yelp...
# 6                True            Review  https://www.yelp...
# 7                True            Review  https://www.yelp...
# 8                True            Review  https://www.yelp...
# 9                True            Review  https://www.yelp...
# 10               True            Review  https://www.yelp...
# 11               True            Review  https://www.yelp...
# 12               True            Review  https://www.yelp...
# 13               True            Review  https://www.yelp...
# 14               True            Review  https://www.yelp...
# 15               True            Review  https://www.yelp...
# 16               True              Call                  NaN
# 17               True            Review  https://www.yelp...
# 18               True            Review  https://www.goog...
# 19               True            Review  https://www.yelp...
# 20               True              Call                  NaN
# 21               True            Review  https://www.yelp...
# 22               True            Review  https://www.yelp...
# 23               True              Call                  NaN
# 24               True            Review  https://www.yelp...
# 25               True            Review  https://www.yelp...
# 26               True            Review  https://www.yelp...
# 27               True            Review  https://www.yelp...
# 28               True            Review  https://www.yelp...
# 29               True            Review  https://www.yelp...
# 30               True            Review  https://www.yelp...
# 31               True            Review  https://www.yelp...
# 32               True            Review  https://www.yelp...
# 33               True            Review  https://www.yelp...
# 34               True            Review  https://www.goog...
# 35               True            Review  https://www.yelp...
# 36               True            Review  https://www.yelp...
# 37               True            Review  https://www.yelp...
# 38               True              Call                  NaN
# 39               True            Review  https://www.goog...
# 40               True            Review  https://www.yelp...
# 41               True            Review  https://www.yelp...
# 42               True            Review  https://www.goog...
# 43               True              Call                  NaN
# 44               True              Call                  NaN
# 45               True            Review  https://www.yelp...
# 46               True            Review  https://www.yelp...
# 47               True            Review  https://www.yelp...
# 48               True            Review  https://www.yelp...
# 49               True            Review  https://www.yelp...
# 50               True            Review  https://www.yelp...
# 51               True            Review  https://www.yelp...
# 52               True            Review  https://www.yelp...
# 53               True            Review  https://www.yelp...
# 54               True            Review  https://www.yelp...
# 55               True            Review  https://www.yelp...
# 56               True              Call                  NaN
# 57               True            Review  https://www.goog...
# 58               True            Review  https://www.yelp...
# 59               True              Call                  NaN
# 60               True              Call                  NaN
# 61               True              Call                  NaN
# 62               True            Review  https://www.yelp...
# 63               True            Review  https://www.goog...
# 64               True              Call                  NaN
# 65               True            Review  https://www.yelp...
# 66               True            Review  https://www.yelp...
# 67               True            Review  https://www.yelp...
# 68               True            Review  https://www.yelp...
# 69               True            Review  https://www.yelp...
# 70               True            Review  https://www.yelp...
# 71               True            Review  https://www.yelp...
# 72               True            Review  https://www.yelp...
# 73              False              Call                  NaN
# 74              False              Call                  NaN
# 75              False              Call                  NaN
# 76              False              Call                  NaN
# 77              False              Call                  NaN
# 78              False              Call                  NaN
# 79              False              Call                  NaN
# 80              False              Call                  NaN
# 81              False            Review  https://www.yelp...
# 82              False              Call                  NaN
# 83              False              Call                  NaN
# 84              False              Call                  NaN
# 85              False              Call                  NaN
# 86              False              Call                  NaN
# 87              False              Call                  NaN
# 88              False              Call                  NaN
#
#                   Notes Census Tract ID    Income  total_pop  \
# 0                   NaN     06037502802   34907.0     3081.0
# 1                   NaN     06111003100  102358.0    14669.0
# 2                   NaN     06001438203   71607.0     4118.0
# 66                  NaN     06013313101   53202.0     7055.0
# 67                  NaN     06037406000   79694.0     5188.0
# 68                  NaN     06029001500   25647.0     2633.0
# 69                  NaN     06089010400   41596.0     4205.0
# 70                  NaN     06019004002   40116.0     7398.0
# 71                  NaN     06073003601   37143.0     2877.0
# 72                  NaN     06037267800   73049.0     2680.0
# 73                  NaN     06037571102  101250.0     3992.0
# 74                  NaN     06047000701   36735.0     3254.0
# 75                  NaN     06097153403   79028.0     3825.0
# 76                  NaN     06071009800   27169.0     5163.0
# 77                  NaN     06097150901   64759.0     5067.0
# 78                  NaN     06037122410   31397.0     3588.0
# 79                  NaN     06095252502   41500.0     2086.0
# 80                  NaN     06107000301   54129.0     7207.0
# 81  Review suggests ...     06037137501   85089.0     4516.0
# 82                  NaN     06037432802   39634.0     5242.0
# 83                  NaN     06037460502  146297.0     4406.0
# 84                  NaN     06037670002   80117.0     3997.0
# 85                  NaN     06087100700   47083.0     1936.0
# 86                  NaN     06081602800  131302.0     4855.0
# 87                  NaN     06039000103   54514.0     5401.0
# 88                  NaN     06037601202   52578.0     3924.0
#
#                geometry % Non-English % Internet  Pop Density
# 0   POLYGON ((-118.0...          18.2       74.4         2356
# 1   POLYGON ((-119.1...           4.8       89.9        10761
# 2   POLYGON ((-122.0...          13.0       89.3         2095
# 3   POLYGON ((-122.5...           6.5       84.0         5578
# 4   POLYGON ((-124.0...           3.4       90.1         2777
# 5   POLYGON ((-120.8...          12.3       73.0         3448
# 6   POLYGON ((-121.8...           2.6       83.0         4616
# 7   POLYGON ((-122.1...           9.9       98.7          205
# 8   POLYGON ((-117.4...           9.8       77.8         6320
# 9   POLYGON ((-117.6...          10.8       90.7         4476
# 10  POLYGON ((-122.5...           4.8       92.0         6488
# 11  POLYGON ((-121.9...          10.2       81.4        11151
# 12  POLYGON ((-122.9...           2.3       75.2         1118
# 13  POLYGON ((-119.0...           8.1       75.6         2900
# 14  POLYGON ((-118.1...           7.3       84.5         8564
# 15  POLYGON ((-119.0...          25.1       58.0         3252
# 16  POLYGON ((-118.2...           4.2       79.2           12
# 17  POLYGON ((-123.0...           0.0       85.5          174
# 18  POLYGON ((-121.7...           4.4       93.0         4322
# 19  POLYGON ((-118.3...           5.6       86.8         6523
# 20  POLYGON ((-119.7...          18.0       61.6         2037
# 21  POLYGON ((-122.0...           4.9       93.4         6398
# 22  POLYGON ((-117.9...          11.0       80.8         2610
# 23  POLYGON ((-121.0...           2.4       83.1         2130
# 24  POLYGON ((-122.0...           6.0       88.0         8948
# 25  POLYGON ((-118.2...          19.5       65.9        21302
# 26  POLYGON ((-122.2...           8.3       83.7        14243
# 27  POLYGON ((-119.3...           2.8       86.1         3566
# 28  POLYGON ((-122.2...          29.1       74.0        16282
# 29  POLYGON ((-118.3...           4.9       80.5        13084
# 30  POLYGON ((-118.1...          19.3       86.9         7936
# 31  POLYGON ((-117.9...           2.3       88.5         9308
# 32  POLYGON ((-122.8...           1.0       90.7         1184
# 33  POLYGON ((-122.5...          28.4       89.2         1981
# 34  POLYGON ((-124.1...           2.3       74.4         1643
# 35  POLYGON ((-118.2...           5.6       70.0         1342
# 36  POLYGON ((-118.1...          16.7       73.9         7211
# 37  POLYGON ((-122.4...          19.8       69.1        35153
# 38  POLYGON ((-119.4...           9.4       78.5         3075
# 39  POLYGON ((-117.6...          34.1       62.7         1293
# 40  POLYGON ((-119.9...           4.3       65.5         2034
# 41  POLYGON ((-120.9...          16.2       83.4         3640
# 42  POLYGON ((-118.1...             -          -            0
# 43  POLYGON ((-120.4...           4.4       82.5         1071
# 44  POLYGON ((-121.0...           4.7       88.0         2153
# 45  POLYGON ((-122.0...          14.0       84.4         9696
# 46  POLYGON ((-118.2...           8.8       88.7        11825
# 47  POLYGON ((-118.1...           1.3       79.5         8876
# 48  POLYGON ((-122.6...           4.0       88.5         4397
# 49  POLYGON ((-117.9...          11.0       80.8         2610
# 50  POLYGON ((-122.2...           7.6       87.9          196
# 51  POLYGON ((-121.5...          11.0       73.2         1348
# 52  POLYGON ((-121.4...          11.0       82.4         7956
# 53  POLYGON ((-122.2...          21.0       78.7        10459
# 54  POLYGON ((-122.4...          20.4       83.9        20247
# 55  POLYGON ((-118.4...          23.8       71.4        13433
# 56  POLYGON ((-120.0...          24.8       56.0         6247
# 57  POLYGON ((-122.5...           5.3       94.2         4788
# 58  POLYGON ((-121.0...           0.5       73.3         2205
# 59  POLYGON ((-117.7...           1.8       90.5         8801
# 60  POLYGON ((-118.1...          22.5       80.6         8452
# 61  POLYGON ((-121.1...           4.5       81.5         2770
# 62  POLYGON ((-118.3...          14.0       80.5        26599
# 63  POLYGON ((-124.0...           0.5       88.0           18
# 64  POLYGON ((-122.2...           0.4       71.1          933
# 65  POLYGON ((-118.8...           6.5       78.4         7864
# 66  POLYGON ((-121.8...           7.9       80.3         5241
# 67  POLYGON ((-117.9...           8.6       84.3         7988
# 68  POLYGON ((-119.0...          25.1       58.0         3252
# 69  POLYGON ((-122.3...           0.0       81.1         1652
# 70  POLYGON ((-120.0...          22.6       66.8          986
# 71  POLYGON ((-117.1...          18.9       68.9        10043
# 72  POLYGON ((-118.4...           8.5       92.9         6823
# 73  POLYGON ((-118.1...           4.8       90.0         9393
# 74  POLYGON ((-120.6...          10.2       82.3         4567
# 75  POLYGON ((-122.8...           1.0       90.7         1184
# 76  POLYGON ((-117.3...          10.8       79.8         4530
# 77  POLYGON ((-122.6...           4.0       88.5         4397
# 78  POLYGON ((-118.3...          25.6       50.7        14906
# 79  POLYGON ((-122.0...           6.4       85.3         6024
# 80  POLYGON ((-119.5...           8.7       74.1          143
# 81  POLYGON ((-118.5...           5.9       92.8         5263
# 82  POLYGON ((-118.0...          38.9       64.8        24977
# 83  POLYGON ((-118.2...           2.2       97.2         5158
# 84  POLYGON ((-118.3...          10.4       89.1        13514
# 85  POLYGON ((-122.0...           0.0       91.1         5784
# 86  POLYGON ((-122.4...           4.5       96.3        10768
# 87  POLYGON ((-119.7...           0.0       81.1           22
# 88  POLYGON ((-118.3...          24.2       87.9        17517
